# %%
# imports
import pandas as pd
from keras import models
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2022-11-09 18:42:13.617142: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# load dataset
df = pd.read_csv('/Users/taylor/Desktop/DS340W/term_project/data/wisconsin/wisconsin_train_balanced.csv')
dataset = df.values

# split into input (X) and output (Y) variables
X = dataset[:,0:30].astype(float)
Y = dataset[:,30]

# encode class values as integers
encoder = LabelEncoder()

encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# %%
# create smaller model (i.e., forced feature extraction)
smallNet = Sequential()
smallNet.add(Dense(15, input_shape=(30,), activation='relu'))
smallNet.add(Dense(1, activation='sigmoid'))
    
# compile and train
smallNet.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
smallNet.fit(X, encoded_Y, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 2022-11-09 18:42:21.026530: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 46/46 [==============================] - 1s 2ms/step - loss: 0.7472 - accuracy: 0.4897
# Epoch 2/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6570 - accuracy: 0.5171
# Epoch 3/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6303 - accuracy: 0.5610
# Epoch 4/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6015 - accuracy: 0.6466
# Epoch 5/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.7075
# Epoch 6/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5262 - accuracy: 0.7788
# Epoch 7/100
# ...

# %%
# save model
smallNet.save('/Users/taylor/Desktop/DS340W/term_project/models/smallNet')
# Out:
# INFO:tensorflow:Assets written to: /Users/taylor/Desktop/DS340W/term_project/models/smallNet/assets
