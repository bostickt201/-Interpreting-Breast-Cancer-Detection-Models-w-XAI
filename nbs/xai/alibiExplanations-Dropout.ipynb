# %%
# imports
import pandas as pd
from keras import models
from sklearn.preprocessing import LabelEncoder

import numpy as np
import matplotlib.pyplot as plt
from alibi.explainers import ALE, plot_ale
from alibi.explainers import IntegratedGradients
from sklearn.preprocessing import StandardScaler
# Out:
# 2022-12-05 00:41:12.850242: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# load datasets
df = pd.read_csv('/Users/taylor/Desktop/DS340W/term_project/data/wisconsin/wisconsin_train_balanced.csv')
dataset = df.values

# split into input (X) and (test_X)
X = dataset[:,0:30].astype(float)

# %%
# Reconstruct models
baseNetDrop = models.load_model('/Users/taylor/Desktop/DS340W/term_project/models/dropout/baseNetDrop')
smallNetDrop = models.load_model('/Users/taylor/Desktop/DS340W/term_project/models/dropout/smallNetDrop')
bigNet5Drop = models.load_model('/Users/taylor/Desktop/DS340W/term_project/models/dropout/bigNet5Drop')
bigNet7Drop = models.load_model('/Users/taylor/Desktop/DS340W/term_project/models/dropout/bigNet7Drop')
bigNet10Drop = models.load_model('/Users/taylor/Desktop/DS340W/term_project/models/dropout/bigNet10Drop')
bigNet15Drop = models.load_model('/Users/taylor/Desktop/DS340W/term_project/models/dropout/bigNet15Drop')
# Out:
# 2022-12-05 00:41:23.073889: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# define ALE params
base_prob_func = baseNetDrop.predict
small_prob_func = smallNetDrop.predict
big5_prob_func = bigNet5Drop.predict
big7_prob_func = bigNet7Drop.predict
big10_prob_func = bigNet10Drop.predict
big15_prob_func = bigNet15Drop.predict

features = ['radius_mean',
                  'texture_mean',
                  'perimeter_mean',
                  'area_mean',
                  'smoothness_mean',
                  'compactness_mean',
                  'concavity_mean',
                  'concave.points_mean',
                  'symmetry_mean',
                  'fractal_dimension_mean',
                  'radius_se',
                  'texture_se',
                  'perimeter_se',
                  'area_se',
                 'smoothness_se',
                 'compactness_se',
                 'concavity_se',
                 'concave.points_se',
                 'symmetry_se',
                 'fractal_dimension_se',
                 'radius_worst',
                 'texture_worst',
                 'perimeter_worst',
                 'area_worst',
                 'smoothness_worst',
                 'compactness_worst',
                 'concavity_worst',
                 'concave.points_worst',
                 'symmetry_worst',
                 'fractal_dimension_worst']

target = ['diagnosis']

# %%
# create ALE objects
base_ale = ALE(base_prob_func, feature_names=features, target_names= target)
small_ale = ALE(small_prob_func, feature_names=features, target_names= target)
big5_ale = ALE(big5_prob_func, feature_names=features, target_names= target)
big7_ale = ALE(big7_prob_func, feature_names=features, target_names= target)
big10_ale = ALE(big10_prob_func, feature_names=features, target_names= target)
big15_ale = ALE(big15_prob_func, feature_names=features, target_names= target)

# %%
# create explainers
baseExplainer = base_ale.explain(X)
smallExplainer = small_ale.explain(X)
big5Explainer = big5_ale.explain(X)
big7Explainer = big7_ale.explain(X)
big10Explainer = big10_ale.explain(X)
big15Explainer = big15_ale.explain(X)
# Out:
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 993us/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 5ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 5ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 1s 9ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 998us/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 6ms/step
# 46/46 [==============================] - 0s 5ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 6ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 4ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 3ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 2ms/step
# 46/46 [==============================] - 0s 3ms/step

# %%
# plot concave.points_mean (i.e., feature 7)
fig, ax = plt.subplots()

plot_ale(baseExplainer, features = ['concave.points_mean'], ax = ax, line_kw = {'label': 'Base Model'})
plot_ale(smallExplainer, features = ['concave.points_mean'], ax = ax, line_kw = {'label': 'Small Model'})
plot_ale(big5Explainer, features = ['concave.points_mean'], ax = ax, line_kw = {'label': 'Big Net 5 Model'})
plot_ale(big7Explainer, features = ['concave.points_mean'], ax = ax, line_kw = {'label': 'Big Net 7 Model'})
plot_ale(big10Explainer, features = ['concave.points_mean'], ax = ax, line_kw = {'label': 'Big Net 10 Model'})
plot_ale(big15Explainer, features = ['concave.points_mean'], ax = ax, line_kw = {'label': 'Big Net 15 Model'})

plt.ylabel('ALE of Diagnosis')
# Out:
# Text(0, 0.5, 'ALE of Diagnosis')

# %%
# plot concavity_mean (i.e., feature 6)
fig, ax = plt.subplots()

plot_ale(baseExplainer, features = ['concavity_mean'], ax = ax, line_kw = {'label': 'Base Model'})
plot_ale(smallExplainer, features = ['concavity_mean'], ax = ax, line_kw = {'label': 'Small Model'})
plot_ale(big5Explainer, features = ['concavity_mean'], ax = ax, line_kw = {'label': 'Big Net 5 Model'})
plot_ale(big7Explainer, features = ['concavity_mean'], ax = ax, line_kw = {'label': 'Big Net 7 Model'})
plot_ale(big10Explainer, features = ['concavity_mean'], ax = ax, line_kw = {'label': 'Big Net 10 Model'})
plot_ale(big15Explainer, features = ['concavity_mean'], ax = ax, line_kw = {'label': 'Big Net 15 Model'})

plt.ylabel('ALE of Diagnosis')
# Out:
# Text(0, 0.5, 'ALE of Diagnosis')

# %%
# plot area_se (i.e., feature 13)
fig, ax = plt.subplots()

plot_ale(baseExplainer, features = ['area_se'], ax = ax, line_kw = {'label': 'Base Model'})
plot_ale(smallExplainer, features = ['area_se'], ax = ax, line_kw = {'label': 'Small Model'})
plot_ale(big5Explainer, features = ['area_se'], ax = ax, line_kw = {'label': 'Big Net 5 Model'})
plot_ale(big7Explainer, features = ['area_se'], ax = ax, line_kw = {'label': 'Big Net 7 Model'})
plot_ale(big10Explainer, features = ['area_se'], ax = ax, line_kw = {'label': 'Big Net 10 Model'})
plot_ale(big15Explainer, features = ['area_se'], ax = ax, line_kw = {'label': 'Big Net 15 Model'})

plt.ylabel('ALE of Diagnosis')
# Out:
# Text(0, 0.5, 'ALE of Diagnosis')

# %%
# plot radius_se (i.e., feature 10)
fig, ax = plt.subplots()

plot_ale(baseExplainer, features = ['radius_se'], ax = ax, line_kw = {'label': 'Base Model'})
plot_ale(smallExplainer, features = ['radius_se'], ax = ax, line_kw = {'label': 'Small Model'})
plot_ale(big5Explainer, features = ['radius_se'], ax = ax, line_kw = {'label': 'Big Net 5 Model'})
plot_ale(big7Explainer, features = ['radius_se'], ax = ax, line_kw = {'label': 'Big Net 7 Model'})
plot_ale(big10Explainer, features = ['radius_se'], ax = ax, line_kw = {'label': 'Big Net 10 Model'})
plot_ale(big15Explainer, features = ['radius_se'], ax = ax, line_kw = {'label': 'Big Net 15 Model'})

plt.ylabel('ALE of Diagnosis')
# Out:
# Text(0, 0.5, 'ALE of Diagnosis')

# %%
# integrated gradients feature importance

# %%
def plot_importance(feat_imp, feat_names, class_idx, **kwargs):
    """
    Create a horizontal barchart of feature effects, sorted by their magnitude.
    """

    df = pd.DataFrame(data=feat_imp, columns=feat_names).sort_values(by=0, axis='columns')
    feat_imp, feat_names = df.values[0], df.columns
    fig, ax = plt.subplots(figsize=(10, 5))
    y_pos = np.arange(len(feat_imp))
    ax.barh(y_pos, feat_imp)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(feat_names, fontsize=7)
    ax.invert_yaxis()
    ax.set_xlabel(f'Feature effects for class {class_idx}', fontsize=15)
    return ax, fig

# create prediction instance
x = np.array([[.372,
               .1327,
               .2988,
               .2742,
               .4041,
               .2756,
               0.2443,
               0.3738,
               0.3982,
               0.1856,
               0.0104,
               0.0595,
               0.0041,
               0.01913,
               0.1497,
               0.1762,
               0.1521,
               0.3197,
               0.1204,
               0.0632,
               0.2948,
               0.2399,
               0.2608,
               0.1774,
               0.5126,
               0.3191,
               0.4081,
               0.7192,
               0.3966,
               0.1647]])

# %%
scaler = StandardScaler()
scaler.fit(X)

baseIG = IntegratedGradients(baseNetDrop,
                         layer=None,
                         method="gausslegendre",
                         n_steps=50,
                         internal_batch_size=100)

smallIG = IntegratedGradients(smallNetDrop,
                         layer=None,
                         method="gausslegendre",
                         n_steps=50,
                         internal_batch_size=100)

big5IG = IntegratedGradients(bigNet5Drop,
                         layer=None,
                         method="gausslegendre",
                         n_steps=50,
                         internal_batch_size=100)

big7IG = IntegratedGradients(bigNet7Drop,
                         layer=None,
                         method="gausslegendre",
                         n_steps=50,
                         internal_batch_size=100)

big10IG = IntegratedGradients(bigNet10Drop,
                         layer=None,
                         method="gausslegendre",
                         n_steps=50,
                         internal_batch_size=100)

big15IG = IntegratedGradients(bigNet15Drop,
                         layer=None,
                         method="gausslegendre",
                         n_steps=50,
                         internal_batch_size=100)

baseRes = baseIG.explain(scaler.transform(x), target=0)
smallRes = smallIG.explain(scaler.transform(x), target=0)
big5Res = big5IG.explain(scaler.transform(x), target=0)
big7Res = big7IG.explain(scaler.transform(x), target=0)
big10Res = big10IG.explain(scaler.transform(x), target=0)
big15Res = big15IG.explain(scaler.transform(x), target=0)

# %%
plot_importance(baseRes.data['attributions'][0], features, '"having cancer present"')
# Out:
# (<AxesSubplot: xlabel='Feature effects for class "having cancer present"'>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
plot_importance(smallRes.data['attributions'][0], features, '"having cancer present"')
# Out:
# (<AxesSubplot: xlabel='Feature effects for class "having cancer present"'>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
plot_importance(big5Res.data['attributions'][0], features, '"having cancer present"')
# Out:
# (<AxesSubplot: xlabel='Feature effects for class "having cancer present"'>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
plot_importance(big7Res.data['attributions'][0], features, '"having cancer present"')
# Out:
# (<AxesSubplot: xlabel='Feature effects for class "having cancer present"'>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
plot_importance(big10Res.data['attributions'][0], features, '"having cancer present"')
# Out:
# (<AxesSubplot: xlabel='Feature effects for class "having cancer present"'>,
#  <Figure size 1000x500 with 1 Axes>)

# %%
plot_importance(big15Res.data['attributions'][0], features, '"having cancer present"')
# Out:
# (<AxesSubplot: xlabel='Feature effects for class "having cancer present"'>,
#  <Figure size 1000x500 with 1 Axes>)
